# %% [markdown]
# # Model Deployment

# %% [markdown]
# ## T5 SMALL

# %%
# !unzip /content/finetuned_T5_model.zip -d /content/finetuned_T5_model
# Out:
# Archive:  /content/finetuned_T5_model.zip
#   inflating: /content/finetuned_T5_model/tokenizer_config.json
#   inflating: /content/finetuned_T5_model/added_tokens.json
#   inflating: /content/finetuned_T5_model/config.json
#   inflating: /content/finetuned_T5_model/spiece.model
#   inflating: /content/finetuned_T5_model/generation_config.json
#   inflating: /content/finetuned_T5_model/special_tokens_map.json
#   inflating: /content/finetuned_T5_model/model.safetensors

# %%
pip install gradio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.1/54.1 MB 17.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.9/322.9 kB 26.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 97.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 5.6 MB/s eta 0:00:00
# ...

# %%
import gradio as gr
from transformers import T5Tokenizer, T5ForConditionalGeneration
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model_name = "finetuned_T5_model"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)

def generate_subject(text):
    input_ids = tokenizer.encode(
        f"summarize: {text}",
        return_tensors="pt",
        max_length=50,
        truncation=True,
        padding="max_length"
    ).to(device)
    output_ids = model.generate(
        input_ids,
        max_length=15,
        num_beams=5,
        early_stopping=True
    )
    return tokenizer.decode(output_ids[0], skip_special_tokens=True)
# Out:
# Red Cedars

# %%
test_sentence = '''Dear Hiring Manager,
I wanted to follow up on my application for the Marketing Analyst position submitted last week. I’m very enthusiastic about the opportunity to join your team and contribute my skills. Please let me know if any additional information is needed.
Best regards,
Jane Doe'''
print(generate_subject(test_sentence))
# Out:
# Marketing Analyst Position

# %%
gr.Interface(
    fn=generate_subject,
    inputs=gr.Textbox(lines=5, placeholder="Paste email body here..."),
    outputs="text",
    title="Subject Line Generator",
    description="Generates a subject line based on the email body using a fine-tuned T5 model."
).launch()
# Out:
# It looks like you are running Gradio on a hosted a Jupyter notebook. For the Gradio app to work, sharing must be enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://e02b8f9be278fc06dd.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://e02b8f9be278fc06dd.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## BART

# %%
# !unzip /content/finetuned_bart_model.zip -d /content/finetuned_bart_model
# Out:
# Archive:  /content/finetuned_bart_model.zip
#   inflating: /content/finetuned_bart_model/tokenizer_config.json
#   inflating: /content/finetuned_bart_model/merges.txt
#   inflating: /content/finetuned_bart_model/vocab.json
#   inflating: /content/finetuned_bart_model/generation_config.json
#   inflating: /content/finetuned_bart_model/model.safetensors
#   inflating: /content/finetuned_bart_model/special_tokens_map.json
#   inflating: /content/finetuned_bart_model/config.json

# %%
import gradio as gr
from transformers import BartTokenizer, BartForConditionalGeneration
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model_name = "finetuned_bart_model"
tokenizer = BartTokenizer.from_pretrained(model_name)
model = BartForConditionalGeneration.from_pretrained(model_name)

def generate_subject(text):
    input_ids = tokenizer.encode(
        f"summarize: {text}",
        return_tensors="pt",
        max_length=50,
        truncation=True,
        padding="max_length"
    ).to(device)
    output_ids = model.generate(
        input_ids,
        max_length=15,
        num_beams=5,
        early_stopping=True
    )
    return tokenizer.decode(output_ids[0], skip_special_tokens=True)

# %%
gr.Interface(
    fn=generate_subject,
    inputs=gr.Textbox(lines=5, placeholder="Paste email body here..."),
    outputs="text",
    title="Subject Line Generator",
    description="Generates a subject line based on the email body using a fine-tuned BART model."
).launch()
# Out:
# It looks like you are running Gradio on a hosted a Jupyter notebook. For the Gradio app to work, sharing must be enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://0f3b1a13cbc7b10f07.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://0f3b1a13cbc7b10f07.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
